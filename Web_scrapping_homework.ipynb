# %% [markdown]
# #### Домашнее задание к лекции "Основы веб-скрапинга и работы с API"
# ##### Задание 1.
# Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
# KEYWORDS = ['python', 'парсинг']
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import pandas as pd

# %%
keywords = ['python', 'парсинг']
#keywords = ['Netology']
url = 'https://habr.com/ru/all'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.text, 'html.parser')
links = soup.find_all('a', class_='post__title_link')
habr_news = pd.DataFrame()
for link in links:
    href = link.attrs.get('href')
    response = requests.get(href)
    time.sleep(0.3)
    article = BeautifulSoup(response.text, 'html.parser')
    post = article.find('div', id = 'post-content-body').get_text()
    for word in keywords:
        a = re.search(word, post, flags=re.IGNORECASE)
        if a is not None:
            date = pd.to_datetime(article.find('span', class_ = 'post__time').get('data-time_published')).date()
            title = article.find('span', class_ = 'post__title-text').text
            row = {'date': date, 'title': title, 'link': href}
            habr_news = pd.concat([habr_news, pd.DataFrame([row])])  
            #print(row)
            break
if len(habr_news) > 0:
    display(habr_news.reset_index())
else:
    print(f'Ключевые слова {keywords} не найдены')
# Out:
#    index        date                                              title  \
# 0      0  2021-05-29  В аквариуме: вычислительная генетика на Python...
# 1      0  2021-05-29  Как создавать предметы генеративного искусства...
#
#                                                 link
# 0                   https://habr.com/ru/post/559908/
# 1  https://habr.com/ru/company/skillfactory/blog/...

# %% [markdown]
# Дополнительная часть (необязательная)
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
soup = BeautifulSoup(req.text, 'html.parser')
links = soup.find_all('a', class_='post__title_link')
habr_news = pd.DataFrame()
for link in links:
    href = link.attrs.get('href')
    response = requests.get(href)
    time.sleep(0.3)
    article = BeautifulSoup(response.text, 'html.parser')
    post = article.find('div', id = 'post-content-body').get_text()
    for word in keywords:
        a = re.search(word, post, flags=re.IGNORECASE)
        if a is not None:
            date = pd.to_datetime(article.find('span', class_ = 'post__time').get('data-time_published')).date()
            title = article.find('span', class_ = 'post__title-text').text
            content = article.find('div', class_ = 'post__body').text
            row = {'date': date, 'title': title, 'link': href, 'content': content}
            habr_news = pd.concat([habr_news, pd.DataFrame([row])])  
            #print(row)
            break
if len(habr_news) > 0:
    display(habr_news.reset_index())
else:
    print(f'Ключевые слова {keywords} не найдены')
# Out:
#    index        date                                              title  \
# 0      0  2021-05-29  В аквариуме: вычислительная генетика на Python...
# 1      0  2021-05-29  Как создавать предметы генеративного искусства...
#
#                                                 link  \
# 0                   https://habr.com/ru/post/559908/
# 1  https://habr.com/ru/company/skillfactory/blog/...
#
#                                              content
# 0  \nПусть в аквариуме живут рыбки двух цветов. Н...
# 1  \nМы уже писали о поле течений, при помощи кот...

# %% [markdown]
# ##### Задание 2.
# Обязательная часть
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Check. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
# В итоге должен формироваться датафрейм со столбцами: <дата утечки> - <источник утечки> - <описание утечки>
# Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import json

url = "https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data"

payload = {"emailAddresses":["fff@mail.ru"]}

# Поиск того, какие ключи надо подставить, чтобы определить, где находится информация о взломах эл. адреса, самостоятельно
# не сделала. На лекции такого не объясняли. Обращалась за помощью к своему источнику. Без помощи бы не справилась. 
# Принципы поиска внутри html-кода остались неусвоенными, очень большая структура кода, кроме заголовков, текста, 
# простой разметки, ссылок, остальной код остается непонятным.
# Вставляю рекомендацию по ДЗ: При некорректных ответах от сервиса можно смело подставлять в запрос абсолютно все заголовки, 
# какие только есть, это точно сработает. Кроме того при ошибочном ответе, в его содержимом можно посмотреть ошибку о том, 
# какого заголовка не хватает. 
# Для данного случая ничего не меняю, т.к. примененные заголовки и были найдены путем добавления недостающего заголовка 
# через запуск программы Postman (отслеживает пришедшие ответы с веб-сервисов)
headers = {
    'Content-Type': "application/json",
    'Vaar-Version': "0",
    'Vaar-Header-App-Product': "hackcheck-web-avast",
    'Vaar-Header-App-Product-Name': "hackcheck-web-avast",
    'Vaar-Header-App-Build-Version': "1.0.0",
    }

response = requests.post(url, data=json.dumps(payload), headers=headers)
breaches = json.loads(response.text)
breaches
# Не всегда срабатывает, т.к. сайт https://www.avast.com/hackcheck регулярно запрашивает про "Я не робот".
# Out:
# {'breaches': {'25953': {'breachId': 25953,
#    'site': 'ta-bao.com',
#    'recordsCount': 240992,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 239943, 'emails': 240992}},
#   '16372': {'breachId': 16372,
#    'site': 'bookmate.com',
#    'recordsCount': 7775238,
#    'description': 'In July 2018, Bookmate was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This data has been sold on at least one dark web market and is also being privately shared among several criminal networks.\r\n',
#    'publishDate': '2019-03-20T00:00:00Z',
#    'statistics': {'usernames': 7775230,
#     'passwords': 2547574,
#     'emails': 3822191}},
#   '17665': {'breachId': 17665,
#    'site': 'stalker.so',
#    'recordsCount': 1300204,
#    'description': 'In January 2020, the Russian multiplayer video game Stalker Online was allegedly breached. The stolen data contains usernames, IPs, passwords, and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-05-28T00:00:00Z',
#    'statistics': {'usernames': 812994,
#     'passwords': 1300050,
#     'emails': 1298521}},
#   '16982': {'breachId': 16982,
#    'site': 'ozonemc.ru',
#    'recordsCount': 1132757,
#    'description': 'At an unconfirmed date, two Russian Minecraft server databases (OzoneMC and FireMC) were allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-10-10T00:00:00Z',
#    'statistics': {'usernames': 1132752,
#     'passwords': 1132757,
#     'emails': 202211}},
#   '16587': {'breachId': 16587,
#    'site': 'dubsmash.com',
#    'recordsCount': 161162574,
#    'description': "In December 2018, Dubsmash's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-03-07T00:00:00Z',
#    'statistics': {'usernames': 159256428,
#     'passwords': 161154927,
#     'emails': 161146252}},
#   '3717': {'breachId': 3717,
#    'site': 'lookbook.nu',
#    'recordsCount': 1079920,
#    'description': "In October 2016, fashion blog Lookbook's database was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-05-09T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 910446, 'emails': 1079920}},
#   '22246': {'breachId': 22246,
#    'site': 'pfv.gostika.ru',
#    'recordsCount': 219877,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 219673, 'emails': 219877}},
#   '16868': {'breachId': 16868,
#    'site': 'borealis.su',
#    'recordsCount': 349061,
#    'description': "At an unconfirmed date, Russian Minecraft server Borealis.su's database was allegedly breached. The stolen data contains usernames, passwords, and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-08-08T00:00:00Z',
#    'statistics': {'usernames': 349054, 'passwords': 349039, 'emails': 345545}},
#   '17433': {'breachId': 17433,
#    'site': 'romwe.com',
#    'recordsCount': 20310339,
#    'description': 'At an unconfirmed date, the online fashion retailer ROMWE was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-02T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 17683990, 'emails': 20301726}},
#   '36055': {'breachId': 36055,
#    'site': 'btravel.ru',
#    'recordsCount': 68669,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 68658, 'emails': 68669}},
#   '17830': {'breachId': 17830,
#    'site': 'wattpad.com',
#    'recordsCount': 273322456,
#    'description': 'In June 2020, the online writing community Wattpad was allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-07-23T00:00:00Z',
#    'statistics': {'usernames': 270846321,
#     'passwords': 192540751,
#     'emails': 273004868}},
#   '18385': {'breachId': 18385,
#    'site': 'artonline.ru',
#    'recordsCount': 149728,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 149326, 'emails': 149728}},
#   '35214': {'breachId': 35214,
#    'site': 'alrage.ru',
#    'recordsCount': 4056,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 4045, 'emails': 4056}},
#   '17363': {'breachId': 17363,
#    'site': 'shop.westwing.ru',
#    'recordsCount': 1572192,
#    'description': 'In November 2019, the Russian interior design Westwing Shop was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-02-20T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1560850, 'emails': 1571986}},
#   '16665': {'breachId': 16665,
#    'site': 'shein.com',
#    'recordsCount': 41454777,
#    'description': "In June 2018, fast-fashion retailer Shein's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-05-16T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 40976790, 'emails': 41454777}},
#   '16569': {'breachId': 16569,
#    'site': 'd3scene.com',
#    'recordsCount': 568072,
#    'description': "In January 2019, D3Scene's database was allegedly breached. The stolen data contains usernames, IPs, passwords, salts, and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-02-28T00:00:00Z',
#    'statistics': {'usernames': 568022, 'passwords': 568072, 'emails': 568014}},
#   '16768': {'breachId': 16768,
#    'site': 'canva.com',
#    'recordsCount': 137434010,
#    'description': "In May 2019, graphic-design site Canva's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-06-13T00:00:00Z',
#    'statistics': {'usernames': 137304104,
#     'passwords': 61348974,
#     'emails': 137402835}},
#   '22306': {'breachId': 22306,
#    'site': 'egrul-piter.ru',
#    'recordsCount': 193684,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 192290, 'emails': 193684}},
#   '37502': {'breachId': 37502,
#    'site': 'swordfantasy.com',
#    'recordsCount': 3202149,
#    'description': 'At an unknown date, the forum for SwordFantasy Online was allegedly breached. The stolen data contains email addresses, passwords, salts, IPs, usernames and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2021-05-20T00:00:00Z',
#    'statistics': {'usernames': 3198793,
#     'passwords': 3202109,
#     'emails': 2697796}},
#   '33360': {'breachId': 33360,
#    'site': 'crc2.ru',
#    'recordsCount': 28726,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 28652, 'emails': 28726}},
#   '29838': {'breachId': 29838,
#    'site': 'other.shokodrom.ru',
#    'recordsCount': 86677,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 81011, 'emails': 86677}},
#   '37432': {'breachId': 37432,
#    'site': 'crimecraft.mayngames.com',
#    'recordsCount': 784676,
#    'description': 'At an unconfirmed date, the MMO shooter game Crimecraft was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2021-04-29T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 784602, 'emails': 784676}},
#   '17729': {'breachId': 17729,
#    'site': 'd3scene.com',
#    'recordsCount': 970234,
#    'description': 'In June 2019, the online gaming forum D3scene was allegedly breached. The stolen data contains usernames, passwords, IPs, salts, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-06-11T00:00:00Z',
#    'statistics': {'usernames': 970225, 'passwords': 970233, 'emails': 970046}},
#   '17370': {'breachId': 17370,
#    'site': 'excalibur-craft.ru',
#    'recordsCount': 1470812,
#    'description': 'At an unconfirmed date, the Russian Minecraft server Excaliburcraft was allegedly breached. The stolen data contains usernames and passwords. This breach is being privately shared on the internet.',
#    'publishDate': '2020-02-27T00:00:00Z',
#    'statistics': {'usernames': 1470809,
#     'passwords': 1192588,
#     'emails': 732539}},
#   '25947': {'breachId': 25947,
#    'site': 'avarum.ru',
#    'recordsCount': 1862,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1850, 'emails': 1862}},
#   '27185': {'breachId': 27185,
#    'site': 'videogames.eprst.ru',
#    'recordsCount': 110427,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 104729, 'emails': 110427}},
#   '16935': {'breachId': 16935,
#    'site': 'xrumer.winguild.ru',
#    'recordsCount': 277201,
#    'description': "At an unconfirmed date, Russian audio equipment retailer Xrumer.Winguild.ru's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.",
#    'publishDate': '2019-09-12T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 275497, 'emails': 277201}},
#   '16866': {'breachId': 16866,
#    'site': 'firstvds.ru',
#    'recordsCount': 125140,
#    'description': "At an unconfirmed date, Russian server hosting service FirstVDS's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-08-08T00:00:00Z',
#    'statistics': {'usernames': 121480, 'passwords': 125051, 'emails': 122444}},
#   '17009': {'breachId': 17009,
#    'site': 'zynga.com',
#    'recordsCount': 216159495,
#    'description': 'In September 2019, the game developer Zynga was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-10-17T00:00:00Z',
#    'statistics': {'usernames': 214648143,
#     'passwords': 134762791,
#     'emails': 159032663}},
#   '17312': {'breachId': 17312,
#    'site': 'cristalix.pe',
#    'recordsCount': 579672,
#    'description': 'In November 2019, the Russian Minecraft server Cristalix was allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-01-16T00:00:00Z',
#    'statistics': {'usernames': 579646, 'passwords': 579490, 'emails': 220827}},
#   '18150': {'breachId': 18150,
#    'site': 'gonitro.com',
#    'recordsCount': 86440975,
#    'description': 'In October 2020, the PDF editor Nitro was allegedly breached. The stolen data contains passwords, IPs, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-11-19T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 18103956, 'emails': 86440757}},
#   '37529': {'breachId': 37529,
#    'site': 'shadowcraft.ru',
#    'recordsCount': 361197,
#    'description': 'At an unknown date, the Russian Minecraft server Shadowcraft was allegedly breached. The stolen data contains passwords, IPs, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2021-05-27T00:00:00Z',
#    'statistics': {'usernames': 155411, 'passwords': 361182, 'emails': 338788}},
#   '22606': {'breachId': 22606,
#    'site': 'mosgrad.ru',
#    'recordsCount': 3105,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 3089, 'emails': 3105}},
#   '23106': {'breachId': 23106,
#    'site': 'tehno.od.ua',
#    'recordsCount': 17976,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 17696, 'emails': 17976}},
#   '17309': {'breachId': 17309,
#    'site': 'gogames.me',
#    'recordsCount': 2037975,
#    'description': 'In December 2019, the online mobile game GoGames was allegedly breached. The stolen data contains usernames, IPs, passwords, salts, email addresses and additional personal information. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-01-16T00:00:00Z',
#    'statistics': {'usernames': 1708313,
#     'passwords': 2037975,
#     'emails': 2029863}},
#   '28819': {'breachId': 28819,
#    'site': 'moskvapiterperm.ru',
#    'recordsCount': 16168,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 16168, 'emails': 16168}},
#   '17822': {'breachId': 17822,
#    'site': 'synergyregions.ru',
#    'recordsCount': 449246,
#    'description': 'At an unconfirmed date, the Russian university Университет синергия was allegedly breached. The stolen data contains passwords, usernames, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-07-16T00:00:00Z',
#    'statistics': {'usernames': 4555, 'passwords': 449214, 'emails': 448860}},
#   '17457': {'breachId': 17457,
#    'site': 'vkmix.com',
#    'recordsCount': 2127865,
#    'description': 'At an unconfirmed date, the Russian social media sharing service VK Mix was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-09T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 2127865, 'emails': 2127865}},
#   '17391': {'breachId': 17391,
#    'site': 'pixlr.com',
#    'recordsCount': 3995633,
#    'description': 'At an unconfirmed date, the online photo editor Pixlr was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-03-05T00:00:00Z',
#    'statistics': {'usernames': 2090003,
#     'passwords': 2016813,
#     'emails': 3918759}},
#   '17427': {'breachId': 17427,
#    'site': 'instaforex.com',
#    'recordsCount': 263484,
#    'description': 'At an unconfirmed date, the online currency platform InstaForex was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-02T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 263171, 'emails': 263484}},
#   '37216': {'breachId': 37216,
#    'site': 'sminecraft.com',
#    'recordsCount': 119879,
#    'description': 'In 2017, the now-defunct Russian Minecraft server SMinecraft was allegedly breached. The stolen data contains passwords, IPs, usernames, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2021-02-25T00:00:00Z',
#    'statistics': {'usernames': 119878, 'passwords': 119878, 'emails': 117603}},
#   '18991': {'breachId': 18991,
#    'site': 'board.iinfo.co.il',
#    'recordsCount': 15636,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 15506, 'emails': 15636}},
#   '18122': {'breachId': 18122,
#    'site': 'vimeworld.ru',
#    'recordsCount': 12537602,
#    'description': 'In January 2018, the Russian Minecraft server VimeWorld was allegedly breached. The stolen data contains email addresses,  passwords and usernames. This breach is being privately shared on the internet.',
#    'publishDate': '2020-11-05T00:00:00Z',
#    'statistics': {'usernames': 9195268,
#     'passwords': 12530713,
#     'emails': 8517817}},
#   '18221': {'breachId': 18221,
#    'site': 'gostika.ru',
#    'recordsCount': 239461,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 238621, 'emails': 239461}},
#   '37244': {'breachId': 37244,
#    'site': 'bestgamer.ru',
#    'recordsCount': 125710,
#    'description': 'In 2021, the Russian gaming website BestGamer was allegedly breached. The stolen data contains passwords, email addresses, and salts. This breach is being privately shared on the internet.',
#    'publishDate': '2021-03-04T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 125710, 'emails': 125710}},
#   '27976': {'breachId': 27976,
#    'site': 'forumy.ru',
#    'recordsCount': 65437,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 63737, 'emails': 65437}},
#   '16659': {'breachId': 16659,
#    'site': 'livejournal.com',
#    'recordsCount': 30485836,
#    'description': "In 2017, social network LiveJournal's database was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being privately shared in the dark web.",
#    'publishDate': '2019-05-23T00:00:00Z',
#    'statistics': {'usernames': 30485732,
#     'passwords': 29634403,
#     'emails': 30482018}},
#   '21868': {'breachId': 21868,
#    'site': 'e-apteka.od.ua',
#    'recordsCount': 8231,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 8218, 'emails': 8231}}},
#  'data': {'swordfantasy.com': {'fff@mail.ru': [{'breachId': 37502,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'bookmate.com': {'fff@mail.ru': [{'breachId': 16372,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'moskvapiterperm.ru': {'fff@mail.ru': [{'breachId': 28819,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'lookbook.nu': {'fff@mail.ru': [{'breachId': 3717,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'other.shokodrom.ru': {'fff@mail.ru': [{'breachId': 29838,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'videogames.eprst.ru': {'fff@mail.ru': [{'breachId': 27185,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'd3scene.com': {'fff@mail.ru': [{'breachId': 16569,
#      'usernameBreached': True,
#      'passwordBreached': True},
#     {'breachId': 17729, 'usernameBreached': True, 'passwordBreached': True}]},
#   'shadowcraft.ru': {'fff@mail.ru': [{'breachId': 37529,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'borealis.su': {'fff@mail.ru': [{'breachId': 16868,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'wattpad.com': {'fff@mail.ru': [{'breachId': 17830,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'crimecraft.mayngames.com': {'fff@mail.ru': [{'breachId': 37432,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'ta-bao.com': {'fff@mail.ru': [{'breachId': 25953,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'forumy.ru': {'fff@mail.ru': [{'breachId': 27976,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'artonline.ru': {'fff@mail.ru': [{'breachId': 18385,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'cristalix.pe': {'fff@mail.ru': [{'breachId': 17312,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'bestgamer.ru': {'fff@mail.ru': [{'breachId': 37244,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'instaforex.com': {'fff@mail.ru': [{'breachId': 17427,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'livejournal.com': {'fff@mail.ru': [{'breachId': 16659,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'alrage.ru': {'fff@mail.ru': [{'breachId': 35214,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'gostika.ru': {'fff@mail.ru': [{'breachId': 18221,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'xrumer.winguild.ru': {'fff@mail.ru': [{'breachId': 16935,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vkmix.com': {'fff@mail.ru': [{'breachId': 17457,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'excalibur-craft.ru': {'fff@mail.ru': [{'breachId': 17370,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'gogames.me': {'fff@mail.ru': [{'breachId': 17309,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'egrul-piter.ru': {'fff@mail.ru': [{'breachId': 22306,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'dubsmash.com': {'fff@mail.ru': [{'breachId': 16587,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'pixlr.com': {'fff@mail.ru': [{'breachId': 17391,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'canva.com': {'fff@mail.ru': [{'breachId': 16768,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vimeworld.ru': {'fff@mail.ru': [{'breachId': 18122,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'tehno.od.ua': {'fff@mail.ru': [{'breachId': 23106,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'avarum.ru': {'fff@mail.ru': [{'breachId': 25947,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'synergyregions.ru': {'fff@mail.ru': [{'breachId': 17822,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'btravel.ru': {'fff@mail.ru': [{'breachId': 36055,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'pfv.gostika.ru': {'fff@mail.ru': [{'breachId': 22246,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'crc2.ru': {'fff@mail.ru': [{'breachId': 33360,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'firstvds.ru': {'fff@mail.ru': [{'breachId': 16866,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'stalker.so': {'fff@mail.ru': [{'breachId': 17665,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'sminecraft.com': {'fff@mail.ru': [{'breachId': 37216,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'mosgrad.ru': {'fff@mail.ru': [{'breachId': 22606,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'romwe.com': {'fff@mail.ru': [{'breachId': 17433,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'shop.westwing.ru': {'fff@mail.ru': [{'breachId': 17363,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'ozonemc.ru': {'fff@mail.ru': [{'breachId': 16982,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'e-apteka.od.ua': {'fff@mail.ru': [{'breachId': 21868,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'gonitro.com': {'fff@mail.ru': [{'breachId': 18150,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'shein.com': {'fff@mail.ru': [{'breachId': 16665,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'zynga.com': {'fff@mail.ru': [{'breachId': 17009,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'board.iinfo.co.il': {'fff@mail.ru': [{'breachId': 18991,
#      'usernameBreached': True,
#      'passwordBreached': True}]}},
#  'summary': {'fff@mail.ru': {'breaches': [25953,
#     16372,
#     17665,
#     16982,
#     16587,
#     3717,
#     22246,
#     16868,
#     17433,
#     36055,
#     17830,
#     18385,
#     35214,
#     17363,
#     16665,
#     16569,
#     16768,
#     22306,
#     37502,
#     33360,
#     29838,
#     37432,
#     17729,
#     17370,
#     25947,
#     27185,
#     16935,
#     16866,
#     17009,
#     17312,
#     18150,
#     37529,
#     22606,
#     23106,
#     17309,
#     28819,
#     17822,
#     17457,
#     17391,
#     17427,
#     37216,
#     18991,
#     18122,
#     18221,
#     37244,
#     27976,
#     16659,
#     21868]}}}

# %%
# Этот код был сразу в ДЗ. Переводит из json в датафрейм по ключам publish_date, site, description
breaches['summary']
leaks = pd.DataFrame()
for mail in breaches['summary']:
#     print(mail)
    for breach in breaches['summary'][mail]["breaches"]:
#         print(breach)
#         print(breaches["breaches"][str(breach)]['description'])
        publish_date = breaches["breaches"][str(breach)]['publishDate']
        site = breaches["breaches"][str(breach)]['site']
        description = breaches["breaches"][str(breach)]['description']
        row = {'publish_date': publish_date, 'site': site, 'description': description}
        leaks = pd.concat([leaks, pd.DataFrame([row])])
leaks
# Out:
#            publish_date                      site  \
# 0  2020-12-03T00:00:00Z                ta-bao.com
# 0  2019-03-20T00:00:00Z              bookmate.com
# 0  2020-05-28T00:00:00Z                stalker.so
# 0  2019-10-10T00:00:00Z                ozonemc.ru
# 0  2019-03-07T00:00:00Z              dubsmash.com
# 0  2019-05-09T00:00:00Z               lookbook.nu
# 0  2020-12-10T00:00:00Z            pfv.gostika.ru
# 0  2019-08-08T00:00:00Z               borealis.su
# 0  2020-04-02T00:00:00Z                 romwe.com
# 0  2020-12-17T00:00:00Z                btravel.ru
# 0  2020-07-23T00:00:00Z               wattpad.com
# 0  2020-12-10T00:00:00Z              artonline.ru
# 0  2020-12-17T00:00:00Z                 alrage.ru
# 0  2020-02-20T00:00:00Z          shop.westwing.ru
# 0  2019-05-16T00:00:00Z                 shein.com
# 0  2019-02-28T00:00:00Z               d3scene.com
# 0  2019-06-13T00:00:00Z                 canva.com
# 0  2020-12-03T00:00:00Z            egrul-piter.ru
# 0  2021-05-20T00:00:00Z          swordfantasy.com
# 0  2020-12-10T00:00:00Z                   crc2.ru
# 0  2020-12-10T00:00:00Z        other.shokodrom.ru
# 0  2021-04-29T00:00:00Z  crimecraft.mayngames.com
# 0  2020-06-11T00:00:00Z               d3scene.com
# 0  2020-12-10T00:00:00Z                 avarum.ru
# 0  2020-12-10T00:00:00Z       videogames.eprst.ru
# 0  2019-09-12T00:00:00Z        xrumer.winguild.ru
# 0  2019-08-08T00:00:00Z               firstvds.ru
# 0  2019-10-17T00:00:00Z                 zynga.com
# 0  2020-01-16T00:00:00Z              cristalix.pe
# 0  2020-11-19T00:00:00Z               gonitro.com
# 0  2020-12-10T00:00:00Z                mosgrad.ru
# 0  2020-12-03T00:00:00Z               tehno.od.ua
# 0  2020-01-16T00:00:00Z                gogames.me
# 0  2020-12-03T00:00:00Z        moskvapiterperm.ru
# 0  2020-07-16T00:00:00Z         synergyregions.ru
# 0  2020-04-09T00:00:00Z                 vkmix.com
# 0  2020-03-05T00:00:00Z                 pixlr.com
# 0  2020-04-02T00:00:00Z            instaforex.com
# 0  2021-02-25T00:00:00Z            sminecraft.com
# 0  2020-12-10T00:00:00Z         board.iinfo.co.il
# 0  2020-11-05T00:00:00Z              vimeworld.ru
# 0  2020-12-10T00:00:00Z                gostika.ru
# 0  2021-03-04T00:00:00Z              bestgamer.ru
# 0  2020-12-03T00:00:00Z                 forumy.ru
# 0  2019-05-23T00:00:00Z           livejournal.com
# 0  2020-12-10T00:00:00Z            e-apteka.od.ua
#
#                                          description
# 0  In November 2020, a collection of over 23,000 ...
# 0  In July 2018, Bookmate was allegedly breached....
# 0  In January 2020, the Russian multiplayer video...
# 0  At an unconfirmed date, two Russian Minecraft ...
# 0  In December 2018, Dubsmash's database was alle...
# 0  In October 2016, fashion blog Lookbook's datab...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, Russian Minecraft serv...
# 0  At an unconfirmed date, the online fashion ret...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In June 2020, the online writing community Wat...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2019, the Russian interior design ...
# 0  In June 2018, fast-fashion retailer Shein's da...
# 0  In January 2019, D3Scene's database was allege...
# 0  In May 2019, graphic-design site Canva's datab...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unknown date, the forum for SwordFantasy...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, the MMO shooter game C...
# 0  In June 2019, the online gaming forum D3scene ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, Russian audio equipmen...
# 0  At an unconfirmed date, Russian server hosting...
# 0  In September 2019, the game developer Zynga wa...
# 0  In November 2019, the Russian Minecraft server...
# 0  In October 2020, the PDF editor Nitro was alle...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In December 2019, the online mobile game GoGam...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, the Russian university...
# 0  At an unconfirmed date, the Russian social med...
# 0  At an unconfirmed date, the online photo edito...
# 0  At an unconfirmed date, the online currency pl...
# 0  In 2017, the now-defunct Russian Minecraft ser...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In January 2018, the Russian Minecraft server ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In 2021, the Russian gaming website BestGamer ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In 2017, social network LiveJournal's database...
# 0  In November 2020, a collection of over 23,000 ...

# %%
# Еще один вариант. Переводит из json в датафрейм по ключам publish_date, site, description
leaks2 = pd.DataFrame()
for key in breaches['breaches']:
    breach = breaches["breaches"][str(key)]
    publish_date = breach['publishDate']
    site = breach['site']
    description = breach['description']
    row = {'publish_date': publish_date, 'site': site, 'description': description}
    leaks2 = pd.concat([leaks2, pd.DataFrame([row])])
leaks2
# Out:
#            publish_date                      site  \
# 0  2020-12-03T00:00:00Z                ta-bao.com
# 0  2019-03-20T00:00:00Z              bookmate.com
# 0  2020-05-28T00:00:00Z                stalker.so
# 0  2019-10-10T00:00:00Z                ozonemc.ru
# 0  2019-03-07T00:00:00Z              dubsmash.com
# 0  2019-05-09T00:00:00Z               lookbook.nu
# 0  2020-12-10T00:00:00Z            pfv.gostika.ru
# 0  2019-08-08T00:00:00Z               borealis.su
# 0  2020-04-02T00:00:00Z                 romwe.com
# 0  2020-12-17T00:00:00Z                btravel.ru
# 0  2020-07-23T00:00:00Z               wattpad.com
# 0  2020-12-10T00:00:00Z              artonline.ru
# 0  2020-12-17T00:00:00Z                 alrage.ru
# 0  2020-02-20T00:00:00Z          shop.westwing.ru
# 0  2019-05-16T00:00:00Z                 shein.com
# 0  2019-02-28T00:00:00Z               d3scene.com
# 0  2019-06-13T00:00:00Z                 canva.com
# 0  2020-12-03T00:00:00Z            egrul-piter.ru
# 0  2021-05-20T00:00:00Z          swordfantasy.com
# 0  2020-12-10T00:00:00Z                   crc2.ru
# 0  2020-12-10T00:00:00Z        other.shokodrom.ru
# 0  2021-04-29T00:00:00Z  crimecraft.mayngames.com
# 0  2020-06-11T00:00:00Z               d3scene.com
# 0  2020-02-27T00:00:00Z        excalibur-craft.ru
# 0  2020-12-10T00:00:00Z                 avarum.ru
# 0  2020-12-10T00:00:00Z       videogames.eprst.ru
# 0  2019-09-12T00:00:00Z        xrumer.winguild.ru
# 0  2019-08-08T00:00:00Z               firstvds.ru
# 0  2019-10-17T00:00:00Z                 zynga.com
# 0  2020-01-16T00:00:00Z              cristalix.pe
# 0  2020-11-19T00:00:00Z               gonitro.com
# 0  2021-05-27T00:00:00Z            shadowcraft.ru
# 0  2020-12-10T00:00:00Z                mosgrad.ru
# 0  2020-12-03T00:00:00Z               tehno.od.ua
# 0  2020-01-16T00:00:00Z                gogames.me
# 0  2020-12-03T00:00:00Z        moskvapiterperm.ru
# 0  2020-07-16T00:00:00Z         synergyregions.ru
# 0  2020-04-09T00:00:00Z                 vkmix.com
# 0  2020-03-05T00:00:00Z                 pixlr.com
# 0  2020-04-02T00:00:00Z            instaforex.com
# 0  2021-02-25T00:00:00Z            sminecraft.com
# 0  2020-12-10T00:00:00Z         board.iinfo.co.il
# 0  2020-11-05T00:00:00Z              vimeworld.ru
# 0  2020-12-10T00:00:00Z                gostika.ru
# 0  2021-03-04T00:00:00Z              bestgamer.ru
# 0  2020-12-03T00:00:00Z                 forumy.ru
# 0  2019-05-23T00:00:00Z           livejournal.com
# 0  2020-12-10T00:00:00Z            e-apteka.od.ua
#
#                                          description
# 0  In November 2020, a collection of over 23,000 ...
# 0  In July 2018, Bookmate was allegedly breached....
# 0  In January 2020, the Russian multiplayer video...
# 0  At an unconfirmed date, two Russian Minecraft ...
# 0  In December 2018, Dubsmash's database was alle...
# 0  In October 2016, fashion blog Lookbook's datab...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, Russian Minecraft serv...
# 0  At an unconfirmed date, the online fashion ret...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In June 2020, the online writing community Wat...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2019, the Russian interior design ...
# 0  In June 2018, fast-fashion retailer Shein's da...
# 0  In January 2019, D3Scene's database was allege...
# 0  In May 2019, graphic-design site Canva's datab...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unknown date, the forum for SwordFantasy...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, the MMO shooter game C...
# 0  In June 2019, the online gaming forum D3scene ...
# 0  At an unconfirmed date, the Russian Minecraft ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, Russian audio equipmen...
# 0  At an unconfirmed date, Russian server hosting...
# 0  In September 2019, the game developer Zynga wa...
# 0  In November 2019, the Russian Minecraft server...
# 0  In October 2020, the PDF editor Nitro was alle...
# 0  At an unknown date, the Russian Minecraft serv...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In December 2019, the online mobile game GoGam...
# 0  In November 2020, a collection of over 23,000 ...
# 0  At an unconfirmed date, the Russian university...
# 0  At an unconfirmed date, the Russian social med...
# 0  At an unconfirmed date, the online photo edito...
# 0  At an unconfirmed date, the online currency pl...
# 0  In 2017, the now-defunct Russian Minecraft ser...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In January 2018, the Russian Minecraft server ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In 2021, the Russian gaming website BestGamer ...
# 0  In November 2020, a collection of over 23,000 ...
# 0  In 2017, social network LiveJournal's database...
# 0  In November 2020, a collection of over 23,000 ...

# %% [markdown]
# Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>
